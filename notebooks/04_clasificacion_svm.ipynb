# %% [markdown]
# # 4. Clasificación con SVM

# %% [markdown]
# ## 4.1 SentenceTransformer

# %% [markdown]
# ## 4.2 Mex_state (INFOTEC)

# %% [markdown]
# ## 4.3 RoBERTuito

# %% [markdown]
# ## 4.4 Comparativa de Resultados
